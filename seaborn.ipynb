# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import median

# %%
"""we'll use a dataset that contains information about 227 countries.
This dataset has lots of interesting information on each country, 
such as the country's birth rates, death rates, and its gross domestic product (GDP)."""
# Out:
# "we'll use a dataset that contains information about 227 countries.\nThis dataset has lots of interesting information on each country, \nsuch as the country's birth rates, death rates, and its gross domestic product (GDP)."

# %%
countries=pd.read_csv("D:\Data\introduction_sns\countries-of-the-world.csv")
countries.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
countries.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
countries.rename(columns={'Region':"region",'GDP ($ per capita)':'gdp',"Phones (per 1000)":"phones",'Literacy (%)':"percent_literate"},inplace=True)
countries.head()
# Out:
#            Country                               region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)      gdp percent_literate  \
# ...

# %%
# GDP is the value of all the goods and services produced in a year, expressed as dollars per person.
# phones is a list of the number of mobile phones per 1,000 people in that country.

# %%
sns.scatterplot(x=countries.gdp,y=countries.phones)
sns.set(rc={"figure.figsize":(4, 4)})
plt.show()

# %%
sns.scatterplot(x=countries.gdp,y=countries.percent_literate)
sns.set(rc={"figure.figsize":(12, 12)})
plt.show()

# %%
sns.countplot(y="region",data=countries)
# Out:
# <AxesSubplot:xlabel='count', ylabel='region'>

# %%
student_data=pd.read_csv("D:\Data\introduction_sns\student-alcohol-consumption.csv")
student_data
# Out:
#      Unnamed: 0 school sex  age famsize Pstatus  Medu  Fedu  traveltime  \
# 0             0     GP   F   18     GT3       A     4     4           2
# 1             1     GP   F   17     GT3       T     1     1           1
# 2             2     GP   F   15     LE3       T     1     1           1
# 3             3     GP   F   15     GT3       T     4     2           1
# 4             4     GP   F   16     GT3       T     3     3           1
# ..          ...    ...  ..  ...     ...     ...   ...   ...         ...
# 390         390     MS   M   20     LE3       A     2     2           1
# 391         391     MS   M   17     LE3       T     3     1           2
# 392         392     MS   M   21     GT3       T     1     1           1
# 393         393     MS   M   18     LE3       T     3     2           3
# 394         394     MS   M   19     LE3       T     1     1           1
#
#      failures  ... goout Dalc Walc health absences  G1  G2  G3  location  \
# ...

# %%
student_data.columns
# Out:
# Index(['Unnamed: 0', 'school', 'sex', 'age', 'famsize', 'Pstatus', 'Medu',
#        'Fedu', 'traveltime', 'failures', 'schoolsup', 'famsup', 'paid',
#        'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3', 'location', 'study_time'],
#       dtype='object')

# %%
student_data.freetime.value_counts()
# Out:
# 3    157
# 4    115
# 2     64
# 5     40
# 1     19
# Name: freetime, dtype: int64

# %%
student_data.health.value_counts()
# Out:
# 5    146
# 3     91
# 4     66
# 1     47
# 2     45
# Name: health, dtype: int64

# %%
sns.relplot(x="health",y="G3",data=student_data,kind="scatter",size="age",hue="age")

# %%
sns.scatterplot(x="absences",y="G3",data=student_data,hue="location",hue_order=["Rural", "Urban"])
# Out:
# <AxesSubplot:xlabel='absences', ylabel='G3'>

# %%
palette_colors = {"Rural": "green", "Urban": "blue"}

# %%
sns.countplot(x="school",data=student_data,hue="location",palette=palette_colors)
# Out:
# <AxesSubplot:xlabel='school', ylabel='count'>

# %%
sns.relplot(x="absences", y="G3", 
                data=student_data, kind="scatter")

# %%
sns.relplot(x="absences", y="G3", 
                data=student_data, kind="scatter",row="study_time")

# %%
# does a student's first semester grade ("G1") tend to correlate with their final grade ("G3")?


sns.relplot(x="G1", y="G3", data=student_data, kind="scatter")

# %%
student_data['schoolsup']
# Out:
# 0      yes
# 1       no
# 2      yes
# 3       no
# 4       no
#       ...
# 390     no
# 391     no
# 392     no
# 393     no
# 394     no
# Name: schoolsup, Length: 395, dtype: object

# %%
sns.relplot(x="G1", y="G3", data=student_data, kind="scatter", col="schoolsup", col_order=["yes", "no"])

# %%
sns.relplot(x="G1", y="G3", data=student_data, kind="scatter", col="schoolsup", col_order=["yes", "no"], row="famsup",row_order=["yes","no"])

# %%
mpg=pd.read_csv("D:\Data\introduction_sns\mpg.csv")
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
# What is the relationship between the power of a car's engine ("horsepower") and its fuel efficiency ("mpg")? 
# And how does this relationship vary by the number of cylinders ("cylinders") the car has?

sns.relplot(x="horsepower", y="mpg", data=mpg, kind="scatter", size="cylinders",hue="cylinders")

# %% [markdown]
# ##### Conclusion:
# Cars with higher horsepower tend to get a lower number of miles per gallon. They also tend to have a higher number of cylinders.

# %%
# relationship between how fast a car can accelerate ("acceleration") and its fuel efficiency ("mpg"). 
# Do these properties vary by country of origin ("origin")?

sns.relplot(x="acceleration",y="mpg",data=mpg,kind="scatter",style="origin",hue="origin")

# %% [markdown]
# ##### Conclusion:
# Cars from the USA tend to accelerate more quickly and get lower miles per gallon compared to cars from Europe and Japan.

# %%
sns.relplot(x="model_year",y="mpg",data=mpg,kind="line")

# %%
sns.relplot(x="model_year", y="mpg", data=mpg, kind="line",ci="sd")

# %%
# Turn off the confidence intervals on the plot

sns.relplot(x="model_year",y="horsepower",data=mpg,kind="line",ci=None)

# %%
# Create different lines for each country

sns.relplot(x="model_year",y="horsepower",data=mpg,kind="line",ci=None,hue="origin",style="origin")

# %%
sns.relplot(x="model_year",y="horsepower",data=mpg,kind="line",ci=None,hue="origin",style="origin",markers=True)

# %%
sns.relplot(x="model_year",y="horsepower",data=mpg,kind="line",ci=None,style="origin",hue="origin",markers=True,dashes=False)

# %%
survey_data=pd.read_csv("D:\Data\introduction_sns\young-people-survey-responses.csv")
survey_data
# Out:
#       Unnamed: 0  Music  Techno  Movies  History  Mathematics  Pets  Spiders  \
# 0              0    5.0     1.0     5.0      1.0          3.0   4.0      1.0
# 1              1    4.0     1.0     5.0      1.0          5.0   5.0      1.0
# 2              2    5.0     1.0     5.0      1.0          5.0   5.0      1.0
# 3              3    5.0     2.0     5.0      4.0          4.0   1.0      5.0
# 4              4    5.0     2.0     5.0      3.0          2.0   1.0      1.0
# ...          ...    ...     ...     ...      ...          ...   ...      ...
# 1005        1005    5.0     3.0     5.0      4.0          1.0   4.0      2.0
# 1006        1006    4.0     4.0     5.0      4.0          5.0   5.0      1.0
# 1007        1007    4.0     1.0     4.0      2.0          3.0   5.0      2.0
# 1008        1008    5.0     2.0     5.0      3.0          1.0   4.0      3.0
# 1009        1009    5.0     3.0     5.0      2.0          2.0   5.0      1.0
#
# ...

# %%
survey_data.columns
# Out:
# Index(['Unnamed: 0', 'Music', 'Techno', 'Movies', 'History', 'Mathematics',
#        'Pets', 'Spiders', 'Loneliness', 'Parents' advice', 'Internet usage',
#        'Finances', 'Age', 'Siblings', 'Gender', 'Village - town'],
#       dtype='object')

# %%
survey_data.dtypes
# Out:
# Unnamed: 0           int64
# Music              float64
# Techno             float64
# Movies             float64
# History            float64
# Mathematics        float64
# Pets               float64
# Spiders            float64
# Loneliness         float64
# Parents' advice    float64
# Internet usage      object
# Finances           float64
# Age                float64
# Siblings           float64
# Gender              object
# Village - town      object
# dtype: object

# %%
survey_data.Mathematics.value_counts()
# Out:
# 1.0    395
# 3.0    203
# 2.0    194
# 4.0    116
# 5.0     99
# Name: Mathematics, dtype: int64

# %%
mapping={1.0:"worse",2.0:"bad",3.0:"bad",4.0:"good",5.0:"good"}

# %%
survey_data["Interested_in_Math"]=survey_data.Mathematics.map(mapping)

# %%
survey_data
# Out:
#       Unnamed: 0  Music  Techno  Movies  History  Mathematics  Pets  Spiders  \
# 0              0    5.0     1.0     5.0      1.0          3.0   4.0      1.0
# 1              1    4.0     1.0     5.0      1.0          5.0   5.0      1.0
# 2              2    5.0     1.0     5.0      1.0          5.0   5.0      1.0
# 3              3    5.0     2.0     5.0      4.0          4.0   1.0      5.0
# 4              4    5.0     2.0     5.0      3.0          2.0   1.0      1.0
# ...          ...    ...     ...     ...      ...          ...   ...      ...
# 1005        1005    5.0     3.0     5.0      4.0          1.0   4.0      2.0
# 1006        1006    4.0     4.0     5.0      4.0          5.0   5.0      1.0
# 1007        1007    4.0     1.0     4.0      2.0          3.0   5.0      2.0
# 1008        1008    5.0     2.0     5.0      3.0          1.0   4.0      3.0
# 1009        1009    5.0     3.0     5.0      2.0          2.0   5.0      1.0
#
# ...

# %%
survey_data.Age.value_counts()
# Out:
# 19.0    210
# 20.0    194
# 21.0    127
# 18.0    123
# 22.0     84
# 17.0     53
# 23.0     47
# 25.0     30
# 16.0     29
# 24.0     28
# 28.0     17
# 26.0     15
# 27.0     14
# 15.0     11
# 29.0     11
# 30.0     10
# Name: Age, dtype: int64

# %% [markdown]
# ### Visualizing a Categorical and a Quantitative Variable

# %%
sns.catplot(y="Internet usage",data=survey_data,kind="count")

# %%
sns.catplot(y="Internet usage",data=survey_data,kind="count",col="Gender")

# %%
sns.catplot(y="Internet usage",data=survey_data,kind="count",col="Village - town")

# %%
sns.catplot(x="Gender",y="Mathematics",data=survey_data,kind="bar")

# %%
student_data
# Out:
#      Unnamed: 0 school sex  age famsize Pstatus  Medu  Fedu  traveltime  \
# 0             0     GP   F   18     GT3       A     4     4           2
# 1             1     GP   F   17     GT3       T     1     1           1
# 2             2     GP   F   15     LE3       T     1     1           1
# 3             3     GP   F   15     GT3       T     4     2           1
# 4             4     GP   F   16     GT3       T     3     3           1
# ..          ...    ...  ..  ...     ...     ...   ...   ...         ...
# 390         390     MS   M   20     LE3       A     2     2           1
# 391         391     MS   M   17     LE3       T     3     1           2
# 392         392     MS   M   21     GT3       T     1     1           1
# 393         393     MS   M   18     LE3       T     3     2           3
# 394         394     MS   M   19     LE3       T     1     1           1
#
#      failures  ... goout Dalc Walc health absences  G1  G2  G3  location  \
# ...

# %%
sns.catplot(x="study_time",y="G3",data=student_data,kind="bar")

# %%
category_order = ["<2 hours", "2 to 5 hours", "5 to 10 hours", ">10 hours"]

# %%
sns.catplot(x="study_time", y="G3", data=student_data, kind="bar", order=category_order,ci=None)

# %%
study_time_order = ["<2 hours", "2 to 5 hours", 
                    "5 to 10 hours", ">10 hours"]

sns.catplot(x="study_time",y="G3",data=student_data,kind="box",order=study_time_order)

# %%
student_data.internet
# Out:
# 0       no
# 1      yes
# 2      yes
# 3      yes
# 4       no
#       ...
# 390     no
# 391    yes
# 392     no
# 393    yes
# 394    yes
# Name: internet, Length: 395, dtype: object

# %%
sns.catplot(x="internet",y="G3",data=student_data,kind="box")

# %%
# a box plot with subgroups and omit the outliers

sns.catplot(x="internet",y="G3",data=student_data,kind="box",hue="location",sym="")

# %%
sns.catplot(x="romantic", y="G3",data=student_data, kind="box")

# %%
sns.catplot(x="romantic", y="G3",data=student_data, kind="box", whis=0.5)

# %%
sns.catplot(x="romantic", y="G3", data=student_data, kind="box", whis=[5,95])

# %%
# Set the whiskers at the min and max values

sns.catplot(x="romantic", y="G3", data=student_data, kind="box", whis=[0, 100])

# %%
student_data.absences
# Out:
# 0       6
# 1       4
# 2      10
# 3       2
# 4       4
#        ..
# 390    11
# 391     3
# 392     3
# 393     0
# 394     5
# Name: absences, Length: 395, dtype: int64

# %%
sns.catplot(x="famrel",y="absences",data=student_data,kind="point")

# %%
sns.catplot(x="famrel", y="absences",
			data=student_data,
            kind="point",capsize=0.2)

# %%
# Remove the lines joining the points

sns.catplot(x="famrel", y="absences", data=student_data, kind="point", capsize=0.2,join=False)

# %%
sns.catplot(x="romantic", y="absences", data=student_data, kind="point", hue="school")

# %%
sns.catplot(x="romantic", y="absences", data=student_data, kind="point", hue="school",ci=None)

# %%
sns.catplot(x="romantic", y="absences", data=student_data, kind="point", hue="school", ci=None, estimator=median)

# %%
print(sns.set_style())
# Out:
# None

# %%
sns.set_palette.info
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10972\1837561349.py in <module>
# ----> 1 sns.set_palette.info
#
# AttributeError: 'function' object has no attribute 'info'
